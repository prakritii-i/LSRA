# %%
import numpy as np

# %%
import pandas as pd
df = pd.read_csv("muse_with_english_lyrics_only.csv")
df.drop(["lang"],axis=1,inplace=True)
df.head()
# Out:
#               track     artist final_emotion  \
# 0  'Till I Collapse     Eminem         anger
# 1         St. Anger  Metallica         anger
# 2          Speedin'  Rick Ross         anger
# 3      Bamboo Banga     M.I.A.         anger
# 4        Die MF Die       Dope         anger
#
#                                               lyrics
# 0  'Cause sometimes you just feel tired, feel wea...
# 1  St. Anger 'round my neck\nSt. Anger 'round my ...
# 2  Legendary\nRunners\nYou know me\n\nTrilla\n\nE...
# 3  Road runner, road runner\nGoing hundred mile p...
# 4  I don't need your forgiveness\nI don't need yo...

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download('punkt_tab')  # 👈 new addition for latest NLTK

from nltk.tokenize import word_tokenize
nltk.download('punkt'); nltk.download('wordnet'); nltk.download('stopwords')

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def clean_lyrics(text):
    text = text.lower()
    text = re.sub(r'\[.*?\]', '', text)              # remove [chorus], [verse]
    text = re.sub(r'[^a-z\s]', '', text)             # remove punctuation/numbers
    tokens = word_tokenize(text)
    tokens = [lemmatizer.lemmatize(w) for w in tokens if w not in stop_words]
    return " ".join(tokens)

df["cleaned_lyrics"] = df["lyrics"].apply(clean_lyrics)
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\LENOVO/nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package punkt to C:\Users\LENOVO/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\LENOVO/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\LENOVO/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df.tail()
# Out:
#                    track       artist final_emotion  \
# 45487             spirit     delerium          fear
# 45488             spooky        kevoz          fear
# 45489             spooky  tok tok tok          fear
# 45490               wild     the reds         anger
# 45491  you don't know me     deadbolt          fear
#
#                                                   lyrics  \
# 45487  This is a fucking spiral\nYeah\nI have tested ...
# 45488  Yeah, yeah, yeah\nBrainstorm went crazy on the...
# 45489  I was born in a dump\nMama died and my daddy g...
# 45490  Tooth to bone\nNail to stone, yeah\nPlaces you...
# 45491  Ya ya ya ya ya (4x)\nYou don't know me\nYou'll...
#
#                                           cleaned_lyrics
# 45487  fucking spiral yeah tested limit hatred ive ma...
# 45488  yeah yeah yeah brainstorm went crazy beat dang...
# 45489  born dump mama died daddy got drunk left die g...
# 45490  tooth bone nail stone yeah place never go ooh ...
# 45491  ya ya ya ya ya x dont know youll never never p...

# %%
df["cleaned_lyrics"].replace("", np.nan, inplace=True)
df.dropna(subset=["cleaned_lyrics"], inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_29960\3445437197.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["cleaned_lyrics"].replace("", np.nan, inplace=True)

# %%
df.head()
# Out:
#               track     artist final_emotion  \
# 0  'Till I Collapse     Eminem         anger
# 1         St. Anger  Metallica         anger
# 2          Speedin'  Rick Ross         anger
# 3      Bamboo Banga     M.I.A.         anger
# 4        Die MF Die       Dope         anger
#
#                                               lyrics  \
# 0  'Cause sometimes you just feel tired, feel wea...
# 1  St. Anger 'round my neck\nSt. Anger 'round my ...
# 2  Legendary\nRunners\nYou know me\n\nTrilla\n\nE...
# 3  Road runner, road runner\nGoing hundred mile p...
# 4  I don't need your forgiveness\nI don't need yo...
#
#                                       cleaned_lyrics
# 0  cause sometimes feel tired feel weak feel weak...
# 1  st anger round neck st anger round neck never ...
# 2  legendary runner know trilla every dollar coun...
# 3  road runner road runner going hundred mile per...
# 4  dont need forgiveness dont need hate dont need...

# %%
df.to_csv("cleaned_muse_with_english_lyrics_only.csv", index=False)
